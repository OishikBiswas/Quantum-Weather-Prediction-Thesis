# %%
! pip install qiskit
# Out:
# Requirement already satisfied: qiskit in /opt/conda/lib/python3.10/site-packages (0.45.3)
# Requirement already satisfied: qiskit-terra==0.45.3 in /opt/conda/lib/python3.10/site-packages (from qiskit) (0.45.3)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (5.9.4)
# Requirement already satisfied: rustworkx>=0.13.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (0.13.0)
# Requirement already satisfied: ply>=3.10 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (3.11)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (1.11.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.17 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (1.23.5)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (4.9.0)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (0.9.2)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (0.3.7)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit) (1.9.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.3->qiskit) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.3->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra==0.45.3->qiskit) (1.2.1)

# %%
! pip install qiskit-machine-learning
# Out:
# Requirement already satisfied: qiskit-machine-learning in /opt/conda/lib/python3.10/site-packages (0.6.1)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.10/site-packages (from qiskit-machine-learning) (5.9.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-machine-learning) (1.4.0)
# Requirement already satisfied: qiskit-terra>=0.22.2 in /opt/conda/lib/python3.10/site-packages (from qiskit-machine-learning) (0.45.3)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.10/site-packages (from qiskit-machine-learning) (1.9.3)
# Requirement already satisfied: fastdtw in /opt/conda/lib/python3.10/site-packages (from qiskit-machine-learning) (0.3.4)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-machine-learning) (65.5.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from qiskit-machine-learning) (1.23.5)
# Requirement already satisfied: dill>=0.3.4 in /opt/conda/lib/python3.10/site-packages (from qiskit-machine-learning) (0.3.7)
# Requirement already satisfied: rustworkx>=0.13.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (2.8.2)
# Requirement already satisfied: ply>=3.10 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (3.11)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (4.1.1)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (0.9.2)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (1.11.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (4.9.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->qiskit-machine-learning) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->qiskit-machine-learning) (3.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.22.2->qiskit-machine-learning) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.22.2->qiskit-machine-learning) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra>=0.22.2->qiskit-machine-learning) (1.2.1)

# %%
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from qiskit import *

# External imports
from pylab import cm
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt

# Qiskit imports
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.visualization import circuit_drawer
from qiskit.algorithms.optimizers import SPSA

from qiskit.circuit.library import PauliFeatureMap
from qiskit.circuit.library import ZZFeatureMap
from qiskit_machine_learning.kernels import TrainableFidelityQuantumKernel
from qiskit_machine_learning.kernels.algorithms import QuantumKernelTrainer
from qiskit_machine_learning.algorithms import QSVC
from qiskit_machine_learning.datasets import ad_hoc_data

from qiskit.utils import QuantumInstance
from qiskit_machine_learning.kernels import QuantumKernel

import random
import time
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
# Out:
# /tmp/ipykernel_4921/3445415176.py:21: DeprecationWarning: ``qiskit.algorithms`` has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. The ``qiskit.algorithms`` import path is deprecated as of qiskit-terra 0.25.0 and will be removed no earlier than 3 months after the release date. Please run ``pip install qiskit_algorithms`` and use ``import qiskit_algorithms`` instead.
#   from qiskit.algorithms.optimizers import SPSA

# %%
df = pd.read_csv('Thesis IBM Dataset.csv')
df.head()
# Out:
#          Date   Time  Temperature(C)  Feel likes(C)  Chance of Prec.(%)  \
# 0  27-06-2023  08:00              27             32                  21
# 1  27-06-2023  09:00              27             32                  22
# 2  27-06-2023  10:00              28             34                  23
# 3  27-06-2023  11:00              28             33                  30
# 4  27-06-2023  12:00              27             32                  53
#
#    Humidity(%)  Visibity(km)  Pressure(hPa)                    State  \
# 0           87           3.0           1003                  Cloudy
# 1           86           9.0           1003                  Cloudy
# 2           90           3.0           1003                  Cloudy
# 3           85           9.0           1003  Isolated Thunderstroms
# 4           90           9.0           1003                     Rain
#
#   Real State  Rain  Cloudy  Sunny  Fog
# 0     Cloudy   0.0       1      0    0
# 1     Cloudy   0.0       1      0    0
# 2       Rain   1.0       1      0    0
# 3       Rain   1.0       1      0    0
# 4      Sunny   0.0       0      1    0

# %%
df.drop(columns=['Date'], inplace=True)
#df.drop(columns=['Temperature(C)'], inplace=True)
df
# Out:
#        Time  Temperature(C)  Feel likes(C)  Chance of Prec.(%)  Humidity(%)  \
# 0     08:00              27             32                  21           87
# 1     09:00              27             32                  22           86
# 2     10:00              28             34                  23           90
# 3     11:00              28             33                  30           85
# 4     12:00              27             32                  53           90
# ...     ...             ...            ...                 ...          ...
# 4499  19:00              20             20                   1           77
# 4500  20:00              19             19                   1           80
# 4501  21:00              19             19                   2           82
# 4502  22:00              18             18                   2           83
# 4503  23:00              18             18                   2           84
#
#       Visibity(km)  Pressure(hPa)                    State Real State  Rain  \
# 0              3.0           1003                  Cloudy      Cloudy   0.0
# 1              9.0           1003                  Cloudy      Cloudy   0.0
# 2              3.0           1003                  Cloudy        Rain   1.0
# 3              9.0           1003  Isolated Thunderstroms        Rain   1.0
# 4              9.0           1003                     Rain      Sunny   0.0
# ...            ...            ...                      ...        ...   ...
# 4499           8.0           1014                    Clear      Clear   0.0
# 4500          14.0           1015                    Clear      Clear   0.0
# 4501          14.0           1015                    Clear      Clear   0.0
# 4502          14.0           1015                    Clear      Clear   0.0
# 4503          14.0           1015                    Clear      Clear   0.0
#
#       Cloudy  Sunny  Fog
# 0          1      0    0
# 1          1      0    0
# 2          1      0    0
# 3          1      0    0
# 4          0      1    0
# ...      ...    ...  ...
# 4499       0      1    0
# 4500       0      1    0
# 4501       0      1    0
# 4502       0      1    0
# 4503       0      1    0
#
# [4504 rows x 13 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#        Time  Temperature(C)  Feel likes(C)  Chance of Prec.(%)  Humidity(%)  \
# 0     08:00              27             32                  21           87
# 1     09:00              27             32                  22           86
# 2     10:00              28             34                  23           90
# 3     11:00              28             33                  30           85
# 4     12:00              27             32                  53           90
# ...     ...             ...            ...                 ...          ...
# 4499  19:00              20             20                   1           77
# 4500  20:00              19             19                   1           80
# 4501  21:00              19             19                   2           82
# 4502  22:00              18             18                   2           83
# 4503  23:00              18             18                   2           84
#
#       Visibity(km)  Pressure(hPa)                    State Real State  Rain  \
# 0              3.0           1003                  Cloudy      Cloudy   0.0
# 1              9.0           1003                  Cloudy      Cloudy   0.0
# 2              3.0           1003                  Cloudy        Rain   1.0
# 3              9.0           1003  Isolated Thunderstroms        Rain   1.0
# 4              9.0           1003                     Rain      Sunny   0.0
# ...            ...            ...                      ...        ...   ...
# 4499           8.0           1014                    Clear      Clear   0.0
# 4500          14.0           1015                    Clear      Clear   0.0
# 4501          14.0           1015                    Clear      Clear   0.0
# 4502          14.0           1015                    Clear      Clear   0.0
# 4503          14.0           1015                    Clear      Clear   0.0
#
#       Cloudy  Sunny  Fog
# 0          1      0    0
# 1          1      0    0
# 2          1      0    0
# 3          1      0    0
# 4          0      1    0
# ...      ...    ...  ...
# 4499       0      1    0
# 4500       0      1    0
# 4501       0      1    0
# 4502       0      1    0
# 4503       0      1    0
#
# [4503 rows x 13 columns]

# %%
df.drop(columns=['Time', 'State','Real State'], inplace=True)
df
# Out:
#       Temperature(C)  Feel likes(C)  Chance of Prec.(%)  Humidity(%)  \
# 0                 27             32                  21           87
# 1                 27             32                  22           86
# 2                 28             34                  23           90
# 3                 28             33                  30           85
# 4                 27             32                  53           90
# ...              ...            ...                 ...          ...
# 4499              20             20                   1           77
# 4500              19             19                   1           80
# 4501              19             19                   2           82
# 4502              18             18                   2           83
# 4503              18             18                   2           84
#
#       Visibity(km)  Pressure(hPa)  Rain  Cloudy  Sunny  Fog
# 0              3.0           1003   0.0       1      0    0
# 1              9.0           1003   0.0       1      0    0
# 2              3.0           1003   1.0       1      0    0
# 3              9.0           1003   1.0       1      0    0
# 4              9.0           1003   0.0       0      1    0
# ...            ...            ...   ...     ...    ...  ...
# 4499           8.0           1014   0.0       0      1    0
# 4500          14.0           1015   0.0       0      1    0
# 4501          14.0           1015   0.0       0      1    0
# 4502          14.0           1015   0.0       0      1    0
# 4503          14.0           1015   0.0       0      1    0
#
# [4503 rows x 10 columns]

# %%
df.drop(columns=['Sunny','Fog'], inplace=True)

# %%
from qiskit import *

# %%
IBMQ.load_account()
# Out:
# /tmp/ipykernel_4921/485379158.py:1: DeprecationWarning: The package qiskit.providers.ibmq is being deprecated. Please see https://ibm.biz/provider_migration_guide to get instructions on how to migrate to qiskit-ibm-provider (https://github.com/Qiskit/qiskit-ibm-provider) and qiskit-ibm-runtime (https://github.com/Qiskit/qiskit-ibm-runtime).
#   IBMQ.load_account()
# /tmp/ipykernel_4921/485379158.py:1: DeprecationWarning: The qiskit.IBMQ entrypoint and the qiskit-ibmq-provider package (accessible from 'qiskit.providers.ibmq`) are deprecated and will be removed in a future release. Instead you should use the qiskit-ibm-provider package which is accessible from 'qiskit_ibm_provider'. You can install it with 'pip install qiskit_ibm_provider'. Just replace 'qiskit.IBMQ' with 'qiskit_ibm_provider.IBMProvider'
#   IBMQ.load_account()
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
provider.backends()
# Out:
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_statevector') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_mps') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_extended_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_brisbane') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_kyoto') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_osaka') from IBMQ(hub='ibm-q', group='open', project='main')>]

# %%
df
# Out:
#       Temperature(C)  Feel likes(C)  Chance of Prec.(%)  Humidity(%)  \
# 0                 27             32                  21           87
# 1                 27             32                  22           86
# 2                 28             34                  23           90
# 3                 28             33                  30           85
# 4                 27             32                  53           90
# ...              ...            ...                 ...          ...
# 4499              20             20                   1           77
# 4500              19             19                   1           80
# 4501              19             19                   2           82
# 4502              18             18                   2           83
# 4503              18             18                   2           84
#
#       Visibity(km)  Pressure(hPa)  Rain  Cloudy
# 0              3.0           1003   0.0       1
# 1              9.0           1003   0.0       1
# 2              3.0           1003   1.0       1
# 3              9.0           1003   1.0       1
# 4              9.0           1003   0.0       0
# ...            ...            ...   ...     ...
# 4499           8.0           1014   0.0       0
# 4500          14.0           1015   0.0       0
# 4501          14.0           1015   0.0       0
# 4502          14.0           1015   0.0       0
# 4503          14.0           1015   0.0       0
#
# [4503 rows x 8 columns]

# %%
! pip install qiskit_algorithms
# Out:
# Requirement already satisfied: qiskit_algorithms in /opt/conda/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.10/site-packages (from qiskit_algorithms) (1.9.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from qiskit_algorithms) (1.23.5)
# Requirement already satisfied: qiskit>=0.44 in /opt/conda/lib/python3.10/site-packages (from qiskit_algorithms) (0.45.3)
# Requirement already satisfied: qiskit-terra==0.45.3 in /opt/conda/lib/python3.10/site-packages (from qiskit>=0.44->qiskit_algorithms) (0.45.3)
# Requirement already satisfied: rustworkx>=0.13.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (0.13.0)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (5.9.4)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (0.3.7)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (4.9.0)
# Requirement already satisfied: ply>=3.10 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (3.11)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (0.9.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (4.1.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.10/site-packages (from qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (1.11.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra==0.45.3->qiskit>=0.44->qiskit_algorithms) (1.2.1)

# %%
print("Using 3 features Price, Open, High: ")
sz = []
svm_acc = []
qsvm_acc = []
for data_size in range(50, 300, 50):
    print("for size", data_size)
    sz.append(data_size)
    x = df.iloc[:data_size, 0:-1]
    y = df.iloc[:data_size, -1]
    # spltting the dataset into train and test set
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 31)
    from sklearn import svm
    svc_clf = svm.SVC(random_state = 7)
    svc_clf.fit(x_train, y_train)
    svc_score = svc_clf.score(x_test, y_test)
    print(f"svm classification score: {svc_score}")
    svm_acc.append(svc_score)
    import qiskit
    import matplotlib.pyplot as plt
    import numpy as np

    from sklearn.svm import SVC
    from sklearn.cluster import SpectralClustering
    from sklearn.metrics import normalized_mutual_info_score

    from qiskit import BasicAer
    from qiskit.circuit.library import ZZFeatureMap
    from qiskit.utils import QuantumInstance, algorithm_globals
    from qiskit_machine_learning.algorithms import QSVC
    from qiskit_machine_learning.kernels import QuantumKernel
    from qiskit_machine_learning.datasets import ad_hoc_data

    seed = 12345
    algorithm_globals.random_seed = seed
    # Building Kernel
    dse_feature_map = ZZFeatureMap(feature_dimension=4, reps=2, entanglement="linear")

    dse_backend = QuantumInstance(
        BasicAer.get_backend('qasm_simulator'), shots=1024, seed_simulator=seed, seed_transpiler=seed
    )

    dse_kernel = QuantumKernel(feature_map=dse_feature_map, quantum_instance=dse_backend)
    dse_svc = SVC(kernel=dse_kernel.evaluate)
    dse_svc.fit(x_train, y_train)
    dse_score = dse_svc.score(x_test, y_test)

    print(f"qsvm classification test score: {dse_score}")
    qsvm_acc.append(dse_score)
# Out:
# Using 3 features Price, Open, High:
# for size 50
# svm classification score: 0.8
# /tmp/ipykernel_8467/2293736319.py:35: DeprecationWarning: The property ``qiskit.utils.algorithm_globals.QiskitAlgorithmGlobals.random_seed`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. This algorithm utility has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. You can run ``pip install qiskit_algorithms`` and import ``from qiskit_algorithms.utils`` instead.
#   algorithm_globals.random_seed = seed
# /tmp/ipykernel_8467/2293736319.py:39: DeprecationWarning: The class ``qiskit.utils.quantum_instance.QuantumInstance`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/qi_migration.
#   dse_backend = QuantumInstance(
# qsvm classification test score: 0.8
# for size 100
# svm classification score: 1.0
# /tmp/ipykernel_8467/2293736319.py:35: DeprecationWarning: The property ``qiskit.utils.algorithm_globals.QiskitAlgorithmGlobals.random_seed`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. This algorithm utility has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. You can run ``pip install qiskit_algorithms`` and import ``from qiskit_algorithms.utils`` instead.
#   algorithm_globals.random_seed = seed
# /tmp/ipykernel_8467/2293736319.py:39: DeprecationWarning: The class ``qiskit.utils.quantum_instance.QuantumInstance`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/qi_migration.
#   dse_backend = QuantumInstance(
# qsvm classification test score: 1.0
# for size 150
# svm classification score: 0.9333333333333333
# /tmp/ipykernel_8467/2293736319.py:35: DeprecationWarning: The property ``qiskit.utils.algorithm_globals.QiskitAlgorithmGlobals.random_seed`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. This algorithm utility has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. You can run ``pip install qiskit_algorithms`` and import ``from qiskit_algorithms.utils`` instead.
#   algorithm_globals.random_seed = seed
# /tmp/ipykernel_8467/2293736319.py:39: DeprecationWarning: The class ``qiskit.utils.quantum_instance.QuantumInstance`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/qi_migration.
#   dse_backend = QuantumInstance(
# qsvm classification test score: 0.9333333333333333
# for size 200
# svm classification score: 0.975
# /tmp/ipykernel_8467/2293736319.py:35: DeprecationWarning: The property ``qiskit.utils.algorithm_globals.QiskitAlgorithmGlobals.random_seed`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. This algorithm utility has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. You can run ``pip install qiskit_algorithms`` and import ``from qiskit_algorithms.utils`` instead.
#   algorithm_globals.random_seed = seed
# /tmp/ipykernel_8467/2293736319.py:39: DeprecationWarning: The class ``qiskit.utils.quantum_instance.QuantumInstance`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/qi_migration.
#   dse_backend = QuantumInstance(
# qsvm classification test score: 0.975
# for size 250
# svm classification score: 0.94
# /tmp/ipykernel_8467/2293736319.py:35: DeprecationWarning: The property ``qiskit.utils.algorithm_globals.QiskitAlgorithmGlobals.random_seed`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. This algorithm utility has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. You can run ``pip install qiskit_algorithms`` and import ``from qiskit_algorithms.utils`` instead.
#   algorithm_globals.random_seed = seed
# /tmp/ipykernel_8467/2293736319.py:39: DeprecationWarning: The class ``qiskit.utils.quantum_instance.QuantumInstance`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/qi_migration.
#   dse_backend = QuantumInstance(
# qsvm classification test score: 0.94

# %%
print(svm_acc)
print(qsvm_acc)
# Out:
# [0.8, 1.0, 0.9333333333333333, 0.975, 0.94]
# [0.8, 1.0, 0.9333333333333333, 0.975, 0.94]

# %%
sz = [50,100,150,200,250]
svm_acc = [0.8, 1.0, 0.9333333333333333, 0.975, 0.94]
qsvm_acc = [0.8, 1.0, 0.9333333333333333, 0.975, 0.94]

import random
total = 5
for cnt in range(total):
    print("current iteration: ", cnt+1)
    for idx in range(len(sz)):
        data_size = sz[idx]
        print("for size", data_size)
        st = random.randint(0, 300-data_size)
        x = df.iloc[: , :-1]
        x = x[:].values
        y = df.iloc[: , -1]
        # spltting the dataset into train and test set
        from sklearn.model_selection import train_test_split
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 31)
        from sklearn import svm
        svc_clf = svm.SVC(random_state = 7)
        svc_clf.fit(x_train, y_train)
        svc_score = svc_clf.score(x_test, y_test)
        print(f"svm classification score: {svc_score}")
        svm_acc[idx] = svm_acc[idx] + svc_score
        import qiskit
        import matplotlib.pyplot as plt
        import numpy as np

        from sklearn.svm import SVC
        from sklearn.cluster import SpectralClustering
        from sklearn.metrics import normalized_mutual_info_score

        from qiskit import BasicAer
        from qiskit.circuit.library import ZZFeatureMap
        from qiskit.utils import QuantumInstance, algorithm_globals
        from qiskit_machine_learning.algorithms import QSVC
        from qiskit_machine_learning.kernels import QuantumKernel
        from qiskit_machine_learning.datasets import ad_hoc_data

        seed = 12345
        algorithm_globals.random_seed = seed
        # Building Kernel
        dse_feature_map = ZZFeatureMap(feature_dimension=7, reps=2, entanglement="linear")

        dse_backend = QuantumInstance(
            BasicAer.get_backend('qasm_simulator'), shots=1024, seed_simulator=seed, seed_transpiler=seed
        )

        dse_kernel = QuantumKernel(feature_map=dse_feature_map, quantum_instance=dse_backend)
        dse_svc = SVC(kernel=dse_kernel.evaluate)
        dse_svc.fit(x_train, y_train)
        dse_score = dse_svc.score(x_test, y_test)

        print(f"qsvm classification test score: {dse_score}")
        qsvm_acc[idx] = qsvm_acc[idx] + dse_score
    print("=============================================")
# Out:
# current iteration:  1
# for size 50
# svm classification score: 0.8072824156305506
# /tmp/ipykernel_4921/3171747228.py:41: DeprecationWarning: The property ``qiskit.utils.algorithm_globals.QiskitAlgorithmGlobals.random_seed`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. This algorithm utility has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. You can run ``pip install qiskit_algorithms`` and import ``from qiskit_algorithms.utils`` instead.
#   algorithm_globals.random_seed = seed
# /tmp/ipykernel_4921/3171747228.py:45: DeprecationWarning: The class ``qiskit.utils.quantum_instance.QuantumInstance`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/qi_migration.
#   dse_backend = QuantumInstance(
# FAILURE: Can not get job id, Resubmit the qobj to get job id. Terra job error: 'Keyboard interrupt in parallel_map.'
# Process ForkProcess-714:
# Process ForkProcess-716:
# Process ForkProcess-719:
# Process ForkProcess-717:
# Process ForkProcess-720:
# Process ForkProcess-713:
# Process ForkProcess-718:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 103, in get
#     res = self._recv_bytes()
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/lib/python3.10/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 51
#      49 dse_kernel = QuantumKernel(feature_map=dse_feature_map, quantum_instance=dse_backend)
#      50 dse_svc = SVC(kernel=dse_kernel.evaluate)
# ---> 51 dse_svc.fit(x_train, y_train)
#      52 dse_score = dse_svc.score(x_test, y_test)
#      54 print(f"qsvm classification test score: {dse_score}")
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/svm/_base.py:252, in BaseLibSVM.fit(self, X, y, sample_weight)
#     249     print("[LibSVM]", end="")
#     251 seed = rnd.randint(np.iinfo("i").max)
# --> 252 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     253 # see comment on the other call to np.iinfo in this file
#     255 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/svm/_base.py:312, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     308 if callable(self.kernel):
#     309     # you must store a reference to X to compute the kernel in predict
#     310     # TODO: add keyword copy to copy on demand
#     311     self.__Xfit = X
# --> 312     X = self._compute_kernel(X)
#     314     if X.shape[0] != X.shape[1]:
#     315         raise ValueError("X.shape[0] should be equal to X.shape[1]")
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/svm/_base.py:513, in BaseLibSVM._compute_kernel(self, X)
#     509 """Return the data transformed by a callable kernel"""
#     510 if callable(self.kernel):
#     511     # in the case of precomputed kernel given as a function, we
#     512     # have to compute explicitly the kernel matrix
# --> 513     kernel = self.kernel(X, self.__Xfit)
#     514     if sp.issparse(kernel):
#     515         kernel = kernel.toarray()
#
# File /opt/conda/lib/python3.10/site-packages/qiskit_machine_learning/kernels/quantum_kernel.py:519, in QuantumKernel.evaluate(self, x_vec, y_vec)
#     517     kernel = self._calculate_kernel_statevector(x_vec, y_vec, is_symmetric, kernel)
#     518 else:
# --> 519     kernel = self._calculate_kernel(x_vec, y_vec, is_symmetric, kernel)
#     521 return kernel
#
# File /opt/conda/lib/python3.10/site-packages/qiskit_machine_learning/kernels/quantum_kernel.py:654, in QuantumKernel._calculate_kernel(self, x_vec, y_vec, is_symmetric, kernel)
#     649 if self._quantum_instance.bound_pass_manager is not None:
#     650     circuits = self._quantum_instance.transpile(
#     651         circuits, pass_manager=self._quantum_instance.bound_pass_manager
#     652     )
# --> 654 results = self._quantum_instance.execute(circuits, had_transpiled=True)
#     656 matrix_elements = [
#     657     self._compute_overlap(circuit, results) for circuit in range(len(circuits))
#     658 ]
#     660 for (i, j), value in zip(to_be_computed_index, matrix_elements):
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/utils/quantum_instance.py:710, in QuantumInstance.execute(self, circuits, had_transpiled)
#     707                 result.results[n] = tmp_result.results[i]
#     709 else:
# --> 710     result = run_circuits(
#     711         circuits,
#     712         self._backend,
#     713         qjob_config=self.qjob_config,
#     714         backend_options=self.backend_options,
#     715         noise_config=self._noise_config,
#     716         run_config=self._run_config.to_dict(),
#     717         job_callback=self._job_callback,
#     718         max_job_retries=self._max_job_retries,
#     719     )
#     720     self._time_taken += result.time_taken
#     722 if self._circuit_summary:
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/utils/deprecation.py:96, in deprecate_func.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      93 @functools.wraps(func)
#      94 def wrapper(*args, **kwargs):
#      95     warnings.warn(msg, category=category, stacklevel=2)
# ---> 96     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/utils/run_circuits.py:193, in run_circuits(circuits, backend, qjob_config, backend_options, noise_config, run_config, job_callback, max_job_retries)
#     191         count += max_circuits_per_job
#     192 else:
# --> 193     job, job_id = _safe_submit_circuits(
#     194         circuits,
#     195         backend,
#     196         qjob_config=qjob_config,
#     197         backend_options=backend_options,
#     198         noise_config=noise_config,
#     199         run_config=run_config,
#     200         max_job_retries=max_job_retries,
#     201     )
#     202     jobs = [job]
#     203     job_ids = [job_id]
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/utils/run_circuits.py:328, in _safe_submit_circuits(circuits, backend, qjob_config, backend_options, noise_config, run_config, max_job_retries)
#     326 for _ in range(max_job_retries):
#     327     try:
# --> 328         job = _run_circuits_on_backend(
#     329             backend,
#     330             circuits,
#     331             backend_options=backend_options,
#     332             noise_config=noise_config,
#     333             run_config=run_config,
#     334         )
#     335         job_id = job.job_id()
#     336         break
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/utils/run_circuits.py:413, in _run_circuits_on_backend(backend, circuits, backend_options, noise_config, run_config)
#     410         if not hasattr(backend.options, key):
#     411             del run_kwargs[key]
# --> 413 return backend.run(circuits, **run_kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/providers/basicaer/qasm_simulator.py:427, in QasmSimulatorPy.run(self, run_input, **backend_options)
#     425 self._set_options(qobj_config=qobj_options, backend_options=backend_options)
#     426 job_id = str(uuid.uuid4())
# --> 427 job = BasicAerJob(self, job_id, self._run_job(job_id, qobj))
#     428 return job
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/providers/basicaer/qasm_simulator.py:447, in QasmSimulatorPy._run_job(self, job_id, qobj)
#     445 start = time.time()
#     446 for experiment in qobj.experiments:
# --> 447     result_list.append(self.run_experiment(experiment))
#     448 end = time.time()
#     449 result = {
#     450     "backend_name": self.name(),
#     451     "backend_version": self._configuration.backend_version,
#    (...)
#     458     "header": qobj.header.to_dict(),
#     459 }
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/providers/basicaer/qasm_simulator.py:563, in QasmSimulatorPy.run_experiment(self, experiment)
#     561     qubit1 = operation.qubits[1]
#     562     gate = cx_gate_matrix()
# --> 563     self._add_unitary(gate, [qubit0, qubit1])
#     564 # Check if reset
#     565 elif operation.name == "reset":
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/providers/basicaer/qasm_simulator.py:169, in QasmSimulatorPy._add_unitary(self, gate, qubits)
#     167 indexes = einsum_vecmul_index(qubits, self._number_of_qubits)
#     168 # Convert to complex rank-2N tensor
# --> 169 gate_tensor = np.reshape(np.array(gate, dtype=complex), num_qubits * [2, 2])
#     170 # Apply matrix multiplication
#     171 self._statevector = np.einsum(
#     172     indexes, gate_tensor, self._statevector, dtype=complex, casting="no"
#     173 )
#
# KeyboardInterrupt:

# %%
print(svm_acc, qsvm_acc)

# %%
for idx in range(len(sz)):
    print(idx, svm_acc[idx]/10, '\t\t', qsvm_acc[idx]/10)
