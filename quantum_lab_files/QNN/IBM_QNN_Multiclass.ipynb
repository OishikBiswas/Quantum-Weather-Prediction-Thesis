# %%
from qiskit_algorithms.utils import algorithm_globals

algorithm_globals.random_seed = 12345

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Thesis IBM Dataset.csv')
df
# Out:
#             Date   Time  Temperature(C)  Feel likes(C)  Chance of Prec.(%)  \
# 0     27-06-2023  08:00              27             32                  21
# 1     27-06-2023  09:00              27             32                  22
# 2     27-06-2023  10:00              28             34                  23
# 3     27-06-2023  11:00              28             33                  30
# 4     27-06-2023  12:00              27             32                  53
# ...          ...    ...             ...            ...                 ...
# 4499  31-12-2023  19:00              20             20                   1
# 4500  31-12-2023  20:00              19             19                   1
# 4501  31-12-2023  21:00              19             19                   2
# 4502  31-12-2023  22:00              18             18                   2
# 4503  31-12-2023  23:00              18             18                   2
#
#       Humidity(%)  Visibity(km)  Pressure(hPa)                    State  \
# 0              87           3.0           1003                  Cloudy
# 1              86           9.0           1003                  Cloudy
# 2              90           3.0           1003                  Cloudy
# 3              85           9.0           1003  Isolated Thunderstroms
# 4              90           9.0           1003                     Rain
# ...           ...           ...            ...                      ...
# 4499           77           8.0           1014                    Clear
# 4500           80          14.0           1015                    Clear
# 4501           82          14.0           1015                    Clear
# 4502           83          14.0           1015                    Clear
# 4503           84          14.0           1015                    Clear
#
#      Real State  Rain  Cloudy  Sunny  Fog
# 0        Cloudy   0.0       1      0    0
# 1        Cloudy   0.0       1      0    0
# 2          Rain   1.0       1      0    0
# 3          Rain   1.0       1      0    0
# 4         Sunny   0.0       0      1    0
# ...         ...   ...     ...    ...  ...
# 4499      Clear   0.0       0      1    0
# 4500      Clear   0.0       0      1    0
# 4501      Clear   0.0       0      1    0
# 4502      Clear   0.0       0      1    0
# 4503      Clear   0.0       0      1    0
#
# [4504 rows x 14 columns]

# %%
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from qiskit import *

# External imports
from pylab import cm
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt

# Qiskit imports
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.visualization import circuit_drawer
from qiskit.algorithms.optimizers import SPSA

from qiskit.circuit.library import PauliFeatureMap
from qiskit.circuit.library import ZZFeatureMap
from qiskit_machine_learning.kernels import TrainableFidelityQuantumKernel
from qiskit_machine_learning.kernels.algorithms import QuantumKernelTrainer
from qiskit_machine_learning.algorithms import QSVC
from qiskit_machine_learning.datasets import ad_hoc_data

from qiskit.utils import QuantumInstance
from qiskit_machine_learning.kernels import QuantumKernel

import random
import time
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
Final = []
for row in df['Real State']:
        if row=='Rain' or row=='Light Rain' or row=='Heavy Rain' or row=='Heavy rain' or row=='Showers' or row=='showers' or row=='Heavy Thunderstroms' :    Final.append(0)
        elif row=='Cloudy' or row=='Mostly Cloudy' or row=='Mostly cloudy' or row=='cloudy' or row=='Cloudy ':  Final.append(1)
        elif row=='Sunny' or row=='Clear' or row=='Sunny ' or row=='Suuny':  Final.append(2)
        elif row =='Fog' or row=='fog':  Final.append(3)
        elif row=='Thunderstorms' or row=='Thunderstroms' or row=='Isolated Thunderstroms' or row=='Isolated Thunderstorms ' or row=='Isolated Thunderstroms ' or row=='scattered Thunderstorms' or row=='scattered Thunderstroms' or row=='Scattered Thunderstroms' :  Final.append(0)

        else:  Final.append(4)

# %%
df['Final'] = Final

    
df
# Out:
#             Date   Time  Temperature(C)  Feel likes(C)  Chance of Prec.(%)  \
# 0     27-06-2023  08:00              27             32                  21
# 1     27-06-2023  09:00              27             32                  22
# 2     27-06-2023  10:00              28             34                  23
# 3     27-06-2023  11:00              28             33                  30
# 4     27-06-2023  12:00              27             32                  53
# ...          ...    ...             ...            ...                 ...
# 4499  31-12-2023  19:00              20             20                   1
# 4500  31-12-2023  20:00              19             19                   1
# 4501  31-12-2023  21:00              19             19                   2
# 4502  31-12-2023  22:00              18             18                   2
# 4503  31-12-2023  23:00              18             18                   2
#
#       Humidity(%)  Visibity(km)  Pressure(hPa)                    State  \
# 0              87           3.0           1003                  Cloudy
# 1              86           9.0           1003                  Cloudy
# 2              90           3.0           1003                  Cloudy
# 3              85           9.0           1003  Isolated Thunderstroms
# 4              90           9.0           1003                     Rain
# ...           ...           ...            ...                      ...
# 4499           77           8.0           1014                    Clear
# 4500           80          14.0           1015                    Clear
# 4501           82          14.0           1015                    Clear
# 4502           83          14.0           1015                    Clear
# 4503           84          14.0           1015                    Clear
#
#      Real State  Rain  Cloudy  Sunny  Fog  Final
# 0        Cloudy   0.0       1      0    0      1
# 1        Cloudy   0.0       1      0    0      1
# 2          Rain   1.0       1      0    0      0
# 3          Rain   1.0       1      0    0      0
# 4         Sunny   0.0       0      1    0      2
# ...         ...   ...     ...    ...  ...    ...
# 4499      Clear   0.0       0      1    0      2
# 4500      Clear   0.0       0      1    0      2
# 4501      Clear   0.0       0      1    0      2
# 4502      Clear   0.0       0      1    0      2
# 4503      Clear   0.0       0      1    0      2
#
# [4504 rows x 15 columns]

# %%
df.drop(columns=['Date','Time', 'State','Real State','Fog','Sunny','Rain','Cloudy'], inplace=True)
df
# Out:
#       Temperature(C)  Feel likes(C)  Chance of Prec.(%)  Humidity(%)  \
# 0                 27             32                  21           87
# 1                 27             32                  22           86
# 2                 28             34                  23           90
# 3                 28             33                  30           85
# 4                 27             32                  53           90
# ...              ...            ...                 ...          ...
# 4499              20             20                   1           77
# 4500              19             19                   1           80
# 4501              19             19                   2           82
# 4502              18             18                   2           83
# 4503              18             18                   2           84
#
#       Visibity(km)  Pressure(hPa)  Final
# 0              3.0           1003      1
# 1              9.0           1003      1
# 2              3.0           1003      0
# 3              9.0           1003      0
# 4              9.0           1003      2
# ...            ...            ...    ...
# 4499           8.0           1014      2
# 4500          14.0           1015      2
# 4501          14.0           1015      2
# 4502          14.0           1015      2
# 4503          14.0           1015      2
#
# [4504 rows x 7 columns]

# %%
X = df.drop(['Final','Visibity(km)','Pressure(hPa)'], axis='columns')
Y = df.Final

# %%
X = X[:].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
from sklearn import model_selection, datasets, svm
from qiskit import QuantumCircuit, Aer, IBMQ, QuantumRegister, ClassicalRegister
import qiskit
import numpy as np
import copy
import matplotlib.pyplot as plt

# %%
print(Y_train)
# Out:
# 266     1
# 1114    0
# 63      1
# 3265    2
# 1564    2
#        ..
# 4426    2
# 466     0
# 3092    2
# 3772    2
# 860     1
# Name: Final, Length: 3378, dtype: int64

# %%
print(X_train)
# Out:
# [[30 37 52 77]
#  [28 35 93 92]
#  [27 31 18 82]
#  ...
#  [22 22  3 95]
#  [28 30  1 59]
#  [28 34 14 90]]

# %%
X_train
# Out:
# array([[30, 37, 52, 77],
#        [28, 35, 93, 92],
#        [27, 31, 18, 82],
#        ...,
#        [22, 22,  3, 95],
#        [28, 30,  1, 59],
#        [28, 34, 14, 90]])

# %%
N=6
def feature_map(X) :
    q = QuantumRegister(N)
    c = ClassicalRegister(1)
    qc = QuantumCircuit(q,c)
    
    for i, x in enumerate(X) :
        qc.rx(x, i)
        
    return qc, c

# %%
def variational_circuit(qc, theta):
    
    for i in range(N-1):
        qc.cnot(i, i+1)
    qc.cnot(N-1, 0)
    for i in range(N):
        qc.ry(theta[i], i)
    return qc

# %%
def quantum_nn(X, theta, simulator=True):
    
    qc, c = feature_map(X)
    qc = variational_circuit(qc, theta)
    qc.measure(0,c)
    
    shots = 1E4
    backend = Aer.get_backend('qasm_simulator')
    
    if simulator == False:
        
        shots = 5000
        provider = IBMQ.load_account()
        backend = provider.get_backend('ibmq_athens')
        
    job = qiskit.execute(qc, backend, shots=shots)
    result = job.result()
    counts = result.get_counts(qc)
    
    return(counts['1']/shots)

# %%
def loss (prediction, target):
    return (prediction - target)**2

# %%
def gradient(X, Y, theta):
    
    delta = 0.01
    grad = []
    for i in range(len(theta)):
        
        dtheta = copy.copy(theta)
        dtheta[i] += delta
        
        pred1 = quantum_nn(X, dtheta)
        pred2 = quantum_nn(X, theta)
        
        grad.append((loss(pred1, Y) - loss(pred2, Y)) / delta)
        
    return np.array(grad)

# %%
def accuracy(X, Y, theta):
    
    counter = 0
    for X_i, Y_i in zip(X, Y):
        
        prediction = quantum_nn(X_i, theta)
        
        if prediction < 0.5 and Y_i == 0:
            counter += 1
        elif prediction >= 0.5 and Y_i == 1:
            counter += 1
            
    return counter/len(Y)

# %%
eta = 0.05
loss_list = []
theta = np.ones(N)

print('Epoch \t Loss \t Training Accuracy')

for i in range(10):
    
    loss_tmp = []
    for X_i, Y_i in zip(X_train, Y_train):

        prediction = quantum_nn(X_i, theta)
        loss_tmp.append(loss(prediction, Y_i))
        theta = theta - eta * gradient(X_i, Y_i, theta)
        
    loss_list.append(np.mean(loss_tmp))
    acc = accuracy(X_train, Y_train, theta)
    
    print(f'{i} \t {loss_list[-1]:.3f} \t {acc:.3f}')
# Out:
# Epoch 	 Loss 	 Training Accuracy
# /tmp/ipykernel_2085/2434704148.py:4: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.cnot()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.cx as direct replacement.
#   qc.cnot(i, i+1)
# /tmp/ipykernel_2085/2434704148.py:5: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.cnot()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.cx as direct replacement.
#   qc.cnot(N-1, 0)
# /tmp/ipykernel_2085/2434704148.py:4: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.cnot()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.cx as direct replacement.
#   qc.cnot(i, i+1)
# /tmp/ipykernel_2085/2434704148.py:5: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.cnot()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.cx as direct replacement.
#   qc.cnot(N-1, 0)
# 0 	 1.973 	 0.239
# 1 	 1.980 	 0.237
# 2 	 1.970 	 0.239
# 3 	 1.977 	 0.236
# 4 	 1.968 	 0.232
# 5 	 1.964 	 0.229
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/inspect.py:3144, in Signature._bind(self, args, kwargs, partial)
#    3143 try:
# -> 3144     arg_val = kwargs.pop(param_name)
#    3145 except KeyError:
#    3146     # We have no value for this parameter.  It's fine though,
#    3147     # if it has a default value, or it is an '*args'-like
#    3148     # parameter, left alone by the processing of positional
#    3149     # arguments.
#
# KeyError: 'recurse'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 14
#      12     prediction = quantum_nn(X_i, theta)
#      13     loss_tmp.append(loss(prediction, Y_i))
# ---> 14     theta = theta - eta * gradient(X_i, Y_i, theta)
#      16 loss_list.append(np.mean(loss_tmp))
#      17 acc = accuracy(X_train, Y_train, theta)
#
# Cell In[26], line 11, in gradient(X, Y, theta)
#       8     dtheta[i] += delta
#      10     pred1 = quantum_nn(X, dtheta)
# ---> 11     pred2 = quantum_nn(X, theta)
#      13     grad.append((loss(pred1, Y) - loss(pred2, Y)) / delta)
#      15 return np.array(grad)
#
# Cell In[24], line 16, in quantum_nn(X, theta, simulator)
#      13     provider = IBMQ.load_account()
#      14     backend = provider.get_backend('ibmq_athens')
# ---> 16 job = qiskit.execute(qc, backend, shots=shots)
#      17 result = job.result()
#      18 counts = result.get_counts(qc)
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/execute_function.py:286, in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, shots, memory, seed_simulator, default_qubit_los, default_meas_los, qubit_lo_range, meas_lo_range, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     283     experiments = pass_manager.run(experiments)
#     284 else:
#     285     # transpiling the circuits using given transpile options
# --> 286     experiments = transpile(
#     287         experiments,
#     288         basis_gates=basis_gates,
#     289         coupling_map=coupling_map,
#     290         backend_properties=backend_properties,
#     291         initial_layout=initial_layout,
#     292         seed_transpiler=seed_transpiler,
#     293         optimization_level=optimization_level,
#     294         backend=backend,
#     295     )
#     297 if schedule_circuit:
#     298     experiments = schedule(
#     299         circuits=experiments,
#     300         backend=backend,
#    (...)
#     303         method=scheduling_method,
#     304     )
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/compiler/transpiler.py:404, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     399     else:
#     400         instruction_durations = _parse_instruction_durations(
#     401             backend, instruction_durations, dt, circuits[0]
#     402         )
# --> 404 pm = generate_preset_pass_manager(
#     405     optimization_level,
#     406     backend=backend,
#     407     target=target,
#     408     basis_gates=basis_gates,
#     409     inst_map=inst_map,
#     410     coupling_map=coupling_map,
#     411     instruction_durations=instruction_durations,
#     412     backend_properties=backend_properties,
#     413     timing_constraints=timing_constraints,
#     414     initial_layout=initial_layout,
#     415     layout_method=layout_method,
#     416     routing_method=routing_method,
#     417     translation_method=translation_method,
#     418     scheduling_method=scheduling_method,
#     419     approximation_degree=approximation_degree,
#     420     seed_transpiler=seed_transpiler,
#     421     unitary_synthesis_method=unitary_synthesis_method,
#     422     unitary_synthesis_plugin_config=unitary_synthesis_plugin_config,
#     423     hls_config=hls_config,
#     424     init_method=init_method,
#     425     optimization_method=optimization_method,
#     426     _skip_target=_skip_target,
#     427 )
#     428 out_circuits = pm.run(circuits, callback=callback)
#     429 for name, circ in zip(output_name, out_circuits):
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/__init__.py:260, in generate_preset_pass_manager(optimization_level, backend, target, basis_gates, inst_map, coupling_map, instruction_durations, backend_properties, timing_constraints, initial_layout, layout_method, routing_method, translation_method, scheduling_method, approximation_degree, seed_transpiler, unitary_synthesis_method, unitary_synthesis_plugin_config, hls_config, init_method, optimization_method, _skip_target)
#     258     pm = level_0_pass_manager(pm_config)
#     259 elif optimization_level == 1:
# --> 260     pm = level_1_pass_manager(pm_config)
#     261 elif optimization_level == 2:
#     262     pm = level_2_pass_manager(pm_config)
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py:94, in level_1_pass_manager(pass_manager_config)
#      88     pre_optimization = common.generate_pre_op_passmanager(remove_reset_in_zero=False)
#      90 optimization = plugin_manager.get_passmanager_stage(
#      91     "optimization", optimization_method, pass_manager_config, optimization_level=1
#      92 )
# ---> 94 sched = plugin_manager.get_passmanager_stage(
#      95     "scheduling", scheduling_method, pass_manager_config, optimization_level=1
#      96 )
#      98 pre_init = common.generate_control_flow_options_check(
#      99     layout_method=layout_method,
#     100     routing_method=routing_method,
#    (...)
#     105     target=target,
#     106 )
#     107 init = plugin_manager.get_passmanager_stage(
#     108     "init", init_method, pass_manager_config, optimization_level=1
#     109 )
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/plugin.py:259, in PassManagerStagePluginManager.get_passmanager_stage(self, stage_name, plugin_name, pm_config, optimization_level)
#     255     return self._build_pm(
#     256         self.optimization_plugins, stage_name, plugin_name, pm_config, optimization_level
#     257     )
#     258 elif stage_name == "scheduling":
# --> 259     return self._build_pm(
#     260         self.scheduling_plugins, stage_name, plugin_name, pm_config, optimization_level
#     261     )
#     262 else:
#     263     raise TranspilerError(f"Invalid stage name: {stage_name}")
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/plugin.py:276, in PassManagerStagePluginManager._build_pm(self, stage_obj, stage_name, plugin_name, pm_config, optimization_level)
#     274     raise TranspilerError(f"Invalid plugin name {plugin_name} for stage {stage_name}")
#     275 plugin_obj = stage_obj[plugin_name]
# --> 276 return plugin_obj.obj.pass_manager(pm_config, optimization_level)
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/builtin_plugins.py:586, in DefaultSchedulingPassManager.pass_manager(self, pass_manager_config, optimization_level)
#     583 inst_map = pass_manager_config.inst_map
#     584 target = pass_manager_config.target
# --> 586 return common.generate_scheduling(
#     587     instruction_durations, scheduling_method, timing_constraints, inst_map, target
#     588 )
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/common.py:540, in generate_scheduling(instruction_durations, scheduling_method, timing_constraints, inst_map, target)
#     537     def _contains_delay(property_set):
#     538         return property_set["contains_delay"]
# --> 540     scheduling.append(ContainsInstruction("delay"))
#     541     scheduling.append(
#     542         TimeUnitConversion(instruction_durations, target=target), condition=_contains_delay
#     543     )
#     544 if (
#     545     timing_constraints.granularity != 1
#     546     or timing_constraints.min_length != 1
#    (...)
#     549 ):
#     550     # Run alignment analysis regardless of scheduling.
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py:52, in MetaPass.__call__(cls, *args, **kwargs)
#      50 def __call__(cls, *args, **kwargs):
#      51     pass_instance = type.__call__(cls, *args, **kwargs)
# ---> 52     pass_instance._hash = hash(MetaPass._freeze_init_parameters(cls, args, kwargs))
#      53     return pass_instance
#
# File /opt/conda/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py:59, in MetaPass._freeze_init_parameters(class_, args, kwargs)
#      57 self_guard = object()
#      58 init_signature = signature(class_.__init__)
# ---> 59 bound_signature = init_signature.bind(self_guard, *args, **kwargs)
#      60 arguments = [("class_.__name__", class_.__name__)]
#      61 for name, value in bound_signature.arguments.items():
#
# File /opt/conda/lib/python3.10/inspect.py:3182, in Signature.bind(self, *args, **kwargs)
#    3177 def bind(self, /, *args, **kwargs):
#    3178     """Get a BoundArguments object, that maps the passed `args`
#    3179     and `kwargs` to the function's signature.  Raises `TypeError`
#    3180     if the passed arguments can not be bound.
#    3181     """
# -> 3182     return self._bind(args, kwargs)
#
# File /opt/conda/lib/python3.10/inspect.py:3151, in Signature._bind(self, args, kwargs, partial)
#    3144     arg_val = kwargs.pop(param_name)
#    3145 except KeyError:
#    3146     # We have no value for this parameter.  It's fine though,
#    3147     # if it has a default value, or it is an '*args'-like
#    3148     # parameter, left alone by the processing of positional
#    3149     # arguments.
#    3150     if (not partial and param.kind != _VAR_POSITIONAL and
# -> 3151                                         param.default is _empty):
#    3152         raise TypeError('missing a required argument: {arg!r}'. \
#    3153                         format(arg=param_name)) from None
#    3155 else:
#
# File /opt/conda/lib/python3.10/inspect.py:2687, in Parameter.default(self)
#    2683 @property
#    2684 def name(self):
#    2685     return self._name
# -> 2687 @property
#    2688 def default(self):
#    2689     return self._default
#    2691 @property
#    2692 def annotation(self):
#
# KeyboardInterrupt:

# %%
plt.plot(loss_list)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
accuracy(X_test, Y_test, theta)
# Out:
# /tmp/ipykernel_2085/2434704148.py:4: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.cnot()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.cx as direct replacement.
#   qc.cnot(i, i+1)
# /tmp/ipykernel_2085/2434704148.py:5: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.cnot()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use QuantumCircuit.cx as direct replacement.
#   qc.cnot(N-1, 0)
# 0.27175843694493784
